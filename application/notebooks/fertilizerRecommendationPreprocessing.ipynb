# %%
# Import Libraries
import numpy as np 
import pandas as pd

# %%
# Define DataFrame
fertilizerPrediction=pd.read_csv("../../../data/datafertilizerprediction.csv")

# %%
# Set Features as Category
fertilizerPrediction['Fertilizer']=fertilizerPrediction['Fertilizer'].astype('category')
fertilizerPrediction['Soil Type']=fertilizerPrediction['Soil Type'].astype('category')
fertilizerPrediction['Crop Type']=fertilizerPrediction['Crop Type'].astype('category')

# %%
# Convert Category to codes
fertilizerPrediction['Fertilizer']=fertilizerPrediction['Fertilizer'].cat.codes
fertilizerPrediction['Soil Type']=fertilizerPrediction['Soil Type'].cat.codes
fertilizerPrediction['Crop Type']=fertilizerPrediction['Crop Type'].cat.codes

# %%
# Display Final Data
fertilizerPrediction
# Out:
#     Temparature  Humidity  Soil Type  Crop Type  Nitrogen  Potassium
# 0            26        52          4          3        37          0  \
# 1            29        52          2          8        12          0
# 2            34        65          0          1         7          9
# 3            32        62          3          9        22          0
# 4            28        54          1          6        35          0
# ..          ...       ...        ...        ...       ...        ...
# 94           25        50          1          7        24          0
# 95           30        60          3          9         4         17
# 96           38        72          2         10        39          0
# 97           36        60          4          4        15          0
# 98           29        58          0          8        12          0
#
#     Phosphorous  Fertilizer
# 0             0           6
# 1            36           5
# 2            30           1
# 3            20           4
# 4             0           6
# ..          ...         ...
# 94           19           4
# 95           17           0
# 96            0           6
# 97           41           5
# 98           10           3
#
# [99 rows x 8 columns]

# %%
# Export Preprocessed Data
fertilizerPrediction.to_csv("../../../preprocessedData/preprocessedfertilizerprediction.csv")
